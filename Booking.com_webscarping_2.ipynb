# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
url = 'https://www.booking.com/searchresults.html?aid=376363&label=bdot-64N*pl1QD9uXjmSFC82IzgS540988882305%3Apl%3Ata%3Ap1%3Ap22%2C563%2C000%3Aac%3Aap%3Aneg%3Afi%3Atikwd-298413127373%3Alp1012088%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfqnDqqG8nt1XFzPnqOODws&sid=f64edb1e823953457c688b41c548d8bf&tmpl=searchresults&checkin_monthday=29&checkin_year_month=2021-09&checkout_monthday=30&checkout_year_month=2021-09&class_interval=1&dest_id=-3096949&dest_type=city&dr_ps=ISR&dtdisc=0&from_history=1&group_adults=2&group_children=0&highlighted_hotels=2836786&inac=0&index_postcard=0&label_click=undef&no_rooms=1&order=popularity&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&sh_position=1&shw_aparth=1&si=re&si=re&si=re&si=re&si=re&si=re&slp_r_match=0&srpvid=661c33d081a10025&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=25'

# %%
response=requests.get(url,headers=headers)
soup=BeautifulSoup(response.content,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# -->
# <!-- wdot-802 -->
# <html>
#  <head>
#   <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="OSBK0zz08uVisQC" src="https://cf.bstatic.com/libs/privacy-consent/cookie-banner-loader-v3.min.js?type=customer&amp;version=latest&amp;params=nonGDPR%3D1" type="text/javascript">
#   </script>
#   <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <script nonce="OSBK0zz08uVisQC">
# ...

# %%
for item in soup.select('.sr_property_block'):
    try:
        print('----------------------------------------')
        print(item.select('.sr-hotel__name')[0].get_text().strip())
        print(item.select('.hotel_name_link')[0]['href'])
        print(item.select('.bui-review-score__badge')[0].get_text().strip())
        print(item.select('.bui-review-score__text')[0].get_text().strip())
        print(item.select('.bui-review-score__title')[0].get_text().strip())
        #print(item.select('sr_card_address_line__user_destination_address')[0].get_text().strip())
        print(item.select('.hotel_image')[0]['data-highres'])
        print('----------------------------------------')
    except Exception as e:
          #raise e
        print('')
# Out:
# ----------------------------------------
# Batoul Ajyad Hotel
#
# /hotel/sa/batoul-suite.en-gb.html?aid=376363&label=bdot-64N%2Apl1QD9uXjmSFC82IzgS540988882305%3Apl%3Ata%3Ap1%3Ap22%2C563%2C000%3Aac%3Aap%3Aneg%3Afi%3Atikwd-298413127373%3Alp1012088%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfqnDqqG8nt1XFzPnqOODws&sid=c2817b9db27b98ff6582526f3dbcf3bb&all_sr_blocks=283678604_113665616_0_2_0&checkin=2021-09-29&checkout=2021-09-30&dest_id=-3096949&dest_type=city&group_adults=2&group_children=0&hapos=26&highlighted_blocks=283678604_113665616_0_2_0&hpos=1&no_rooms=1&sr_order=popularity&sr_pri_blocks=283678604_113665616_0_2_0__10640&srepoch=1632209978&srpvid=37fa35dc74ab012b&ucfs=1&from=searchresults
# ;highlight_room=;from_sr_card=1#hotelTmpl
# 7.6
# 2,274 reviews
# Good
# https://cf.bstatic.com/xdata/images/hotel/square600/122038722.jpg?k=7b10c97e73e431808259889df51b7d9dbca2e07dc64c388c9fc4be915c4fb8e8&o=
# ----------------------------------------
# ...

# %%
def get_data(tag, class_text, column_name):
    #column_name = []
    for element in soup.find_all(tag, class_ = class_text):
        column_name.append(element.text.strip())
    return column_name

# %%
    name =[]
    rating = []
    review_num = []
    review = []
    distance_from_centre = []





get_data("span", "sr-hotel__name", name)
name
# Out:
# ['Batoul Ajyad Hotel',
#  'Hilton Suites Makkah',
#  'Millennium Makkah Al Naseem',
#  'Snood Al salam',
#  'Lamar Ajyad Hotel',
#  'فندق سنود الريان',
#  'Conrad Makkah',
#  'Makkah Towers',
#  'Sadan Plaza',
#  'Lamar Ajyad Hotel 2 - Tower B',
#  'Doubletree By Hilton Makkah Jabal Omar',
#  'فندق الروضة المكية Alrawda Almakyah Hotel',
#  'Al Waleed Tower Hotel',
#  'Borj Al Deafah Hotel',
#  'لحظة الاحلام للشقق الفندقية',
#  'Makkah Hotel',
#  'Amjad Al Deafah Hotel',
#  'Al Kiswah Towers Hotel',
#  'Nadir Plaza',
#  'فندق الصفوة بلازا',
#  'فندق روز النزهة الفندقية',
#  'فندق رفاف المشاعر',
#  'Al Fajr Al Badea Hotel 3',
#  'Pullman ZamZam Makkah',
#  'فندق أرقى مساء',
#  'فندق هيلا إن مكة']

# %%
get_data("div", "bui-review-score__badge", rating)
rating
# Out:
# ['7.6',
#  '8.8',
#  '8.2',
#  '7.8',
#  '7.8',
#  '7.8',
#  '8.8',
#  '8.1',
#  '7.2',
#  '7.8',
#  '8.6',
#  '8.0',
#  '8.2',
#  '7.5',
#  '8.5',
#  '8.7',
#  '7.8',
#  '8.2',
#  '7.4',
#  '8.7',
#  '6.9',
#  '7.2']

# %%
get_data("div", "bui-review-score__text", review_num)
review_num
# Out:
# ['2,274 reviews',
#  '7,971 reviews',
#  '5,209 reviews',
#  '1,882 reviews',
#  '2,777 reviews',
#  '1,932 reviews',
#  '7,885 reviews',
#  '6,269 reviews',
#  '498 reviews',
#  '2,576 reviews',
#  '1,210 reviews',
#  '244 reviews',
#  '2,879 reviews',
#  '632 reviews',
#  '39 reviews',
#  '4,749 reviews',
#  '1,644 reviews',
#  '4,750 reviews',
#  '91 reviews',
#  '1,107 reviews',
#  '60 reviews',
#  '23,718 reviews']

# %%
get_data("div", "bui-review-score__title", review)
# Out:
# ['Good',
#  'Fabulous',
#  'Very good',
#  'Good',
#  'Good',
#  'Good',
#  'Fabulous',
#  'Very good',
#  'Good',
#  'Good',
#  'Fabulous',
#  'Very good',
#  'Very good',
#  'Good',
#  'Very good',
#  'Fabulous',
#  'Good',
#  'Very good',
#  'Good',
#  'Fabulous',
#  'Review score',
#  'Good']

# %%
get_data("span", "sr_card_address_line__user_destination_address", distance_from_centre)
# Out:
# ['1.7 km from centre',
#  '0.5 km from centre',
#  '6.6 km from centre',
#  '3.3 km from centre',
#  '2.5 km from centre',
#  '1.5 km from centre',
#  '0.6 km from centre',
#  '0.3 km from centre',
#  '1.5 km from centre',
#  '2.4 km from centre',
#  '0.8 km from centre',
#  '2.4 km from centre',
#  '5 km from centre',
#  '1.4 km from centre',
#  '19.2 km from centre',
#  '0.3 km from centre',
#  '1.4 km from centre',
#  '1.5 km from centre',
#  '1.7 km from centre',
#  '3 km from centre',
#  '3.1 km from centre',
#  '5.3 km from centre',
#  '1 km from centre',
#  '0.3 km from centre',
#  '12 km from centre',
#  '3.3 km from centre']

# %%
hotel_df2 = pd.DataFrame(list(zip(name, rating, review_num, review, distance_from_centre)), columns =['hotel_name', 'hotel_rating', 
                                                                                                    'num_reviews', 'review', 'dist_centre'])

# %%
hotel_df2.head(26)
# Out:
#                                    hotel_name hotel_rating     num_reviews  \
# 0                          Batoul Ajyad Hotel          7.6   2,274 reviews
# 1                        Hilton Suites Makkah          8.8   7,971 reviews
# 2                 Millennium Makkah Al Naseem          8.2   5,209 reviews
# 3                              Snood Al salam          7.8   1,882 reviews
# 4                           Lamar Ajyad Hotel          7.8   2,777 reviews
# 5                            فندق سنود الريان          7.8   1,932 reviews
# 6                               Conrad Makkah          8.8   7,885 reviews
# 7                               Makkah Towers          8.1   6,269 reviews
# 8                                 Sadan Plaza          7.2     498 reviews
# 9               Lamar Ajyad Hotel 2 - Tower B          7.8   2,576 reviews
# 10     Doubletree By Hilton Makkah Jabal Omar          8.6   1,210 reviews
# ...

# %%
hotel_df2.to_csv(r'C:/Users/Ashjan/Documents/Sdaya bootcamp/Projects/Regression/Data/Data_File_2.csv', index = False)
